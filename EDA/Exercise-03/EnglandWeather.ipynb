# %% [markdown]
# <div style="
#   text-align: center;
#   margin: 30px 0 25px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h1 style="
#     font-size: 28px;
#     font-weight: 700;
#     color: #1e40af;
#     margin: 0;
#     letter-spacing: -0.5px;
#   ">
#     England Weather
#   </h1>
#   <div style="
#     width: 60px;
#     height: 4px;
#     background: linear-gradient(to right, #3b82f6, #60a5fa);
#     margin: 10px auto 0;
#     border-radius: 2px;
#   "></div>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import colorcet
import matplotlib.colors as mcolors
import seaborn.palettes

# %%
Data = pd.read_csv("EnglandWeather.csv")
df = pd.DataFrame(Data)
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006/04/01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006/04/01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006/04/01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006/04/01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006/04/01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016/09/09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016/09/09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016/09/09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016/09/09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016/09/09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         12.659203          10.810640           1003.235956      0.734899
# std           8.565352           6.913571            116.969906      0.195473
# min           0.000000           0.000000              0.000000      0.000000
# 25%           5.116667           5.828200           1011.900000      0.600000
# 50%          12.061111           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of                       Formatted Date        Summary Precip Type  \
# 0      2006/04/01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006/04/01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006/04/01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006/04/01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006/04/01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016/09/09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016/09/09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016/09/09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016/09/09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016/09/09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %%
df_num = df.select_dtypes('float64')
df_num.describe()
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         12.659203          10.810640           1003.235956      0.734899
# std           8.565352           6.913571            116.969906      0.195473
# min           0.000000           0.000000              0.000000      0.000000
# 25%           5.116667           5.828200           1011.900000      0.600000
# 50%          12.061111           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %%
df_obj = df.select_dtypes("object")
df_obj.describe()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12768\839728021.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df_obj = df.select_dtypes("object")
#                        Formatted Date        Summary Precip Type
# count                           96453          96453       95936
# unique                          96429             27           2
# top     2010/08/02 00:00:00.000 +0200  Partly Cloudy        rain
# freq                                2          31733       85224

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Checking the Missing Values
#   </h2>
# </div>

# %%
df.isna().sum()
# Out:
# Formatted Date            0
# Summary                   0
# Precip Type             517
# Temperature (C)           0
# Wind Speed (km/h)         0
# Pressure (millibars)      0
# Humidity                  0
# dtype: int64

# %%
df.shape
# Out:
# (96453, 7)

# %%
#Reemove missing value

# %%
df1= df.dropna()
df1.isna().sum()
# Out:
# Formatted Date          0
# Summary                 0
# Precip Type             0
# Temperature (C)         0
# Wind Speed (km/h)       0
# Pressure (millibars)    0
# Humidity                0
# dtype: int64

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Edit "Formatted Date" Values
#   </h2>
# </div>

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Create New DataFrame
#   </h2>
# </div>

# %%
df2 = df1.copy()
new = df2["Formatted Date"].str.split(" ",n=2 , expand = True)
new
# Out:
#                 0             1      2
# 0      2006/04/01  00:00:00.000  +0200
# 1      2006/04/01  01:00:00.000  +0200
# 2      2006/04/01  02:00:00.000  +0200
# 3      2006/04/01  03:00:00.000  +0200
# 4      2006/04/01  04:00:00.000  +0200
# ...           ...           ...    ...
# 96448  2016/09/09  19:00:00.000  +0200
# 96449  2016/09/09  20:00:00.000  +0200
# 96450  2016/09/09  21:00:00.000  +0200
# 96451  2016/09/09  22:00:00.000  +0200
# 96452  2016/09/09  23:00:00.000  +0200
#
# [95936 rows x 3 columns]

# %%
df3=df2.drop(columns=["Formatted Date"])
df3.insert(0 , "Date" , new[0],True)
df3
# Out:
#              Date        Summary Precip Type  Temperature (C)  \
# 0      2006/04/01  Partly Cloudy        rain         9.472222
# 1      2006/04/01  Partly Cloudy        rain         9.355556
# 2      2006/04/01  Mostly Cloudy        rain         9.377778
# 3      2006/04/01  Partly Cloudy        rain         8.288889
# 4      2006/04/01  Mostly Cloudy        rain         8.755556
# ...           ...            ...         ...              ...
# 96448  2016/09/09  Partly Cloudy        rain        26.016667
# 96449  2016/09/09  Partly Cloudy        rain        24.583333
# 96450  2016/09/09  Partly Cloudy        rain        22.038889
# 96451  2016/09/09  Partly Cloudy        rain        21.522222
# 96452  2016/09/09  Partly Cloudy        rain        20.438889
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                14.1197               1015.13      0.89
# 1                14.2646               1015.63      0.86
# ...

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Sort the Dataset
#   </h2>
# </div>

# %%
df4=df3.sort_values(by="Date")
df4
# Out:
#              Date        Summary Precip Type  Temperature (C)  \
# 2880   2006/01/01  Partly Cloudy        rain         0.577778
# 2881   2006/01/01  Mostly Cloudy        rain         1.161111
# 2882   2006/01/01  Mostly Cloudy        rain         1.666667
# 2883   2006/01/01       Overcast        rain         1.711111
# 2884   2006/01/01  Mostly Cloudy        rain         1.183333
# ...           ...            ...         ...              ...
# 89728  2016/12/31  Mostly Cloudy        rain         0.488889
# 89729  2016/12/31  Mostly Cloudy        rain         0.072222
# 89730  2016/12/31  Mostly Cloudy        snow         0.233333
# 89731  2016/12/31  Mostly Cloudy        snow         0.472222
# 89732  2016/12/31  Mostly Cloudy        snow         0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 2880             17.1143               1016.66      0.89
# 2881             16.6152               1016.15      0.85
# ...

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Check for Duplicated Values
#   </h2>
# </div>

# %%
print("number of duplicated values : ",len(df4[df4["Date"].duplicated()]))
df4[df4["Date"].duplicated()]
# Out:
# number of duplicated values :  91927
#              Date        Summary Precip Type  Temperature (C)  \
# 2881   2006/01/01  Mostly Cloudy        rain         1.161111
# 2882   2006/01/01  Mostly Cloudy        rain         1.666667
# 2883   2006/01/01       Overcast        rain         1.711111
# 2884   2006/01/01  Mostly Cloudy        rain         1.183333
# 2885   2006/01/01  Mostly Cloudy        rain         1.205556
# ...           ...            ...         ...              ...
# 89728  2016/12/31  Mostly Cloudy        rain         0.488889
# 89729  2016/12/31  Mostly Cloudy        rain         0.072222
# 89730  2016/12/31  Mostly Cloudy        snow         0.233333
# 89731  2016/12/31  Mostly Cloudy        snow         0.472222
# 89732  2016/12/31  Mostly Cloudy        snow         0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 2881             16.6152               1016.15      0.85
# 2882             20.2538               1015.87      0.82
# ...

# %% [markdown]
# <div style="
#   text-align: center;
#   margin: 35px 0 25px;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 1.9rem;
#     font-weight: 700;
#     color: #1e1b4b;
#     margin: 0 0 12px 0;
#     letter-spacing: 0.5px;
#   ">
#     Remove Duplicate Data
#   </h2>
#   <div style="
#     width: 90px;
#     height: 4px;
#     background: linear-gradient(90deg, #6366f1, #a855f7);
#     margin: 0 auto;
#     border-radius: 4px;
#   "></div>
# </div>

# %%
df4_d=df4.drop_duplicates(subset="Date",keep="first")
df4_d
# Out:
#              Date        Summary Precip Type  Temperature (C)  \
# 2880   2006/01/01  Partly Cloudy        rain         0.577778
# 3144   2006/01/02       Overcast        rain         5.422222
# 3408   2006/01/03       Overcast        rain         1.694444
# 3480   2006/01/04       Overcast        rain         2.200000
# 3504   2006/01/05       Overcast        rain         1.666667
# ...           ...            ...         ...              ...
# 89589  2016/12/27  Mostly Cloudy        snow         0.677778
# 89613  2016/12/28  Mostly Cloudy        snow         0.733333
# 89637  2016/12/29  Mostly Cloudy        snow         0.783333
# 89685  2016/12/30  Mostly Cloudy        snow         0.827778
# 89709  2016/12/31  Mostly Cloudy        snow         0.872222
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 2880             17.1143               1016.66      0.89
# 3144             13.6689               1009.60      0.86
# ...

# %%
df5=df4_d.copy()

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Checking the Noise
#   </h2>
# </div>

# %%
plt.figure(figsize=(10,10),dpi=100)
plt.scatter(df5["Summary"],df5["Humidity"] , c="#A12540" , marker="*" , s=40)
plt.grid()
plt.title("Summary  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Summary",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks(rotation=90 , fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")


plt.subplots_adjust(bottom=0.4)
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(df5["Precip Type"],df5["Humidity"] , c="#A12540" , marker="*")
plt.grid()
plt.title("Precip Type  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Precip Type",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks( fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")

plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(df5["Temperature (C)"],df5["Humidity"] , c="#A12540" , marker="*" , s=30)
plt.grid()
plt.title("Temperature   VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Temperature (C)",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks(np.arange(-2 , 46 , 2) , fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")


plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(df5["Wind Speed (km/h)"],df5["Humidity"] , c="#A12540" , marker="*" , s=30)
plt.grid()
plt.title("Wind Speed  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Wind Speed (km/h)",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks( np.arange(0 , 75 , 10),fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")


plt.show()

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Wind Speed (km/h) &lt; 50
#   </h2>
# </div>

# %%
plt.figure(figsize=(9,6))
plt.scatter(df5["Pressure (millibars)"],df5["Humidity"] , c="#A12540" , marker="*")
plt.grid()
plt.title("Pressure  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Pressure (millibars)",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks( np.arange(-0.1 , 1100 , 50),fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")



plt.show()

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Removing the Noises
#   </h2>
# </div>

# %%
df6 = df5[df5['Wind Speed (km/h)']<50]
Df=df6.copy()
Df
# Out:
#              Date        Summary Precip Type  Temperature (C)  \
# 2880   2006/01/01  Partly Cloudy        rain         0.577778
# 3144   2006/01/02       Overcast        rain         5.422222
# 3408   2006/01/03       Overcast        rain         1.694444
# 3480   2006/01/04       Overcast        rain         2.200000
# 3504   2006/01/05       Overcast        rain         1.666667
# ...           ...            ...         ...              ...
# 89589  2016/12/27  Mostly Cloudy        snow         0.677778
# 89613  2016/12/28  Mostly Cloudy        snow         0.733333
# 89637  2016/12/29  Mostly Cloudy        snow         0.783333
# 89685  2016/12/30  Mostly Cloudy        snow         0.827778
# 89709  2016/12/31  Mostly Cloudy        snow         0.872222
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 2880             17.1143               1016.66      0.89
# 3144             13.6689               1009.60      0.86
# ...

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Re-Analysis
#   </h2>
# </div>

# %%
plt.figure(figsize=(10,10))
plt.scatter(Df["Summary"],Df["Humidity"] , c="#A12540" , marker="*")
plt.grid()
plt.title("Summary  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Summary",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks(rotation=90 , fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")


plt.subplots_adjust(bottom=0.4)
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(Df["Precip Type"],Df["Humidity"] , c="#A12540" , marker="*")
plt.grid()
plt.title("Precip Type  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Precip Type",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks( fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")

plt.show()

# %%
plt.figure(figsize=(9,6))
plt.grid()
plt.scatter(Df["Temperature (C)"],Df["Humidity"] , c="#A12540" , marker="*" , s=30)

plt.title("Temperature   VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Temperature (C)",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks(np.arange(-2 , 46 , 2) , fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")


plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(Df["Wind Speed (km/h)"],Df["Humidity"] , c="#A12540" , marker="*" , s=30)
plt.grid()
plt.title("Wind Speed  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Wind Speed (km/h)",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks(np.arange(0 , 75 , 10), fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")



plt.show()

# %%
plt.figure(figsize=(9,6))
plt.grid()
plt.scatter(Df["Pressure (millibars)"],Df["Humidity"] , c="#A12540" , marker="*")

plt.title("Pressure  VS  Humidity" , fontsize=30 ,fontfamily = "Times New Roman" ,pad=10)

plt.xlabel("Pressure (millibars)",fontsize=20 ,fontfamily = "Times New Roman" ,c="red")
plt.ylabel("Hmidity",fontsize=20 ,fontfamily = "Times New Roman",c="red" )

plt.xticks( np.arange(-0.1 , 1100 , 50),fontsize=10 ,fontfamily = "Times New Roman")
plt.yticks(np.arange(-0.1 , 1.2 , 0.1), fontsize=10 ,fontfamily = "Times New Roman")



plt.show()

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Date Analysis
#   </h2>
# </div>

# %%
plt.figure(figsize=(9,9))


year = pd.to_datetime(Df["Date"]).dt.year
sns.countplot(x=year)
plt.grid()

plt.title("Number of samples per Year",  fontsize= 30 , fontfamily = "Times New Roman" , pad= 15)
plt.xlabel("Year" , fontsize= 25 , fontfamily = "Times New Roman" , loc="center")

plt.ylabel("Count" ,  fontsize= 25 , fontfamily = "Times New Roman" , loc="center")
plt.yticks(np.arange(0 , 375, 20))

plt.show()

# %%
plt.figure(figsize=(9,9))


month= pd.to_datetime(Df["Date"]).dt.month
sns.countplot(x=month)




months = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
           'August', 'September', 'October', 'November', 'December']


plt.title("Number of samples per Month",  fontsize= 30 , fontfamily = "Times New Roman" , pad= 15)
plt.xlabel("Month" , fontsize= 25 , fontfamily = "Times New Roman" , loc="center")
# pl.xticklabels(months)
plt.ylabel("Count" ,  fontsize= 25 , fontfamily = "Times New Roman" , loc="center")
plt.yticks(np.arange(0 , 375, 20))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(9,9))


Day= pd.to_datetime(Df["Date"]).dt.day
sns.countplot(x=Day)


plt.title("Number of samples per Day",  fontsize= 30 , fontfamily = "Times New Roman" , pad= 15)
plt.xlabel("Day" , fontsize= 25 , fontfamily = "Times New Roman" , loc="center")
plt.ylabel("Count" ,  fontsize= 25 , fontfamily = "Times New Roman" , loc="center")
plt.yticks(np.arange(0 , 160, 20))
plt.grid()
plt.show()

# %%
sns.set_theme(style="dark")

Df["month"] = pd.to_datetime(Df["Date"]).dt.month
Df["year"] = pd.to_datetime(Df["Date"]).dt.year

months = ['January', 'March', 'May', 'July',
          'September', 'November', '']

# Plot each year's time series in its own facet
g = sns.relplot(
    data=Df,
    x="month",
    y="Humidity",
    col="year",
    hue="year",
    kind="line",
    palette="crest",
    linewidth=4,
    zorder=5,
    col_wrap=2,
    height=4,
    aspect=2
)

# Iterate over each subplot to customize further
for year, ax in g.axes_dict.items():

    ax.text(
        .8, .85, year,
        transform=ax.transAxes,
        fontweight="bold"
    )

    # Plot every year's time series in the background
    sns.lineplot(
        data=Df,
        x="month",
        y="Humidity",
        units="year",
        estimator=None,
        color=".7",
        linewidth=1,
        ax=ax
    )

# Reduce the frequency of the x axis ticks
ax.set_xticklabels(months)

g.set_titles("")
g.set_axis_labels("", "Humidity")
g.tight_layout()
g.add_legend()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12768\3362182280.py:47: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator. Otherwise, ticks may be mislabeled.
#   ax.set_xticklabels(months)

# %% [markdown]
# <div style="
#   margin: 25px 0 15px 0;
#   font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ">
#   <h2 style="
#     font-size: 20px;
#     font-weight: 600;
#     color: #1e40af;
#     margin: 0;
#     display: flex;
#     align-items: center;
#     gap: 8px;
#   ">
#     <span style="
#       display: inline-block;
#       width: 6px;
#       height: 20px;
#       background: #3b82f6;
#       border-radius: 3px;
#     "></span>
#     Individual Feature Analysis
#   </h2>
# </div>

# %%
# Categorizing and counting the number of each category in the "Summary" column
Number_of_categories = Df['Summary'].value_counts()

# Choose 5 categories with more number
top_categories = Number_of_categories.head(5)
print(top_categories)

# Determination of axes
categories = top_categories.index
Number_of_categories = top_categories.values
print(categories)
print(Number_of_categories )

# Chart settings for pie charts
plt.figure(figsize=(10, 10))
plt.pie(Number_of_categories, labels=categories, autopct='%1.1f%%', startangle=90)

plt.title('Pie Chart of Top 5 Data Categories Based on Summary')
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\pieplot.png")
plt.show()
# Out:
# Summary
# Partly Cloudy    1088
# Mostly Cloudy     906
# Overcast          811
# Clear             780
# Foggy             364
# Name: count, dtype: int64
# Index(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Clear', 'Foggy'], dtype='str', name='Summary')
# [1088  906  811  780  364]

# %%
plt.figure(figsize=(10,10))
sns.histplot(data=Df, x="Summary", hue="Precip Type" , color=sns.color_palette("flare", as_cmap=True))
plt.xticks(rotation=90)
plt.yticks(np.arange(0,1300,50))

plt.subplots_adjust(bottom=0.3)
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\summary count.png")

plt.show()

# %%
fig , axes = plt.subplots(figsize=(15,7) , nrows=2, ncols=2)
fig.suptitle('Hist of columns', fontsize=16, fontweight='bold')
i=0
j=0
columns = ['Temperature (C)', 'Wind Speed (km/h)', 'Humidity', 'Pressure (millibars)']
for col in columns:
    sns.histplot(ax=axes[i,j], data=Df, kde=True, x=col, color=sns.color_palette("flare", as_cmap=True) , hue="Precip Type")
    if j == 1:
        i += 1
        j = 0
    else:
        j += 1

plt.tight_layout()
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\hist of columns.png")

plt.show()

# %%
Df
# Out:
#              Date        Summary Precip Type  Temperature (C)  \
# 2880   2006/01/01  Partly Cloudy        rain         0.577778
# 3144   2006/01/02       Overcast        rain         5.422222
# 3408   2006/01/03       Overcast        rain         1.694444
# 3480   2006/01/04       Overcast        rain         2.200000
# 3504   2006/01/05       Overcast        rain         1.666667
# ...           ...            ...         ...              ...
# 89589  2016/12/27  Mostly Cloudy        snow         0.677778
# 89613  2016/12/28  Mostly Cloudy        snow         0.733333
# 89637  2016/12/29  Mostly Cloudy        snow         0.783333
# 89685  2016/12/30  Mostly Cloudy        snow         0.827778
# 89709  2016/12/31  Mostly Cloudy        snow         0.872222
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity  month  year
# 2880             17.1143               1016.66      0.89      1  2006
# 3144             13.6689               1009.60      0.86      1  2006
# ...

# %%
g = sns.PairGrid(Df, hue="Precip Type",  palette="flare" )
g.map_diag(sns.histplot , hue=Df["Precip Type"], color=sns.color_palette("flare", as_cmap=True))
g.map_offdiag(sns.scatterplot )
g.add_legend()
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\PairGrid.png")

# %%
g = sns.PairGrid(Df, hue="Summary",  palette="crest" )
g.map_diag(sns.histplot , hue=Df["Summary"], color=sns.color_palette("cubehelix", as_cmap=True))
g.map_offdiag(sns.scatterplot )
g.add_legend()
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\PairGrid1.png")

# %%
sns.jointplot(data=Df, x="Temperature (C)", y="Humidity", hue="Precip Type")
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\joinplot-humidity-temperature.png")

# %%
sns.jointplot(data=Df, x="Wind Speed (km/h)", y="Humidity", hue="Precip Type")
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\joinplot-humidity-windspead.png")

# %%
precip_summary_count = Df.groupby(['Summary', 'Precip Type']).size().unstack(fill_value=0)

plt.figure(figsize=(18, 12))
sns.heatmap(precip_summary_count, cmap=sns.cubehelix_palette(as_cmap=True) , annot=True, fmt='d', linewidths=.5)
plt.title('Precipitation type status chart and summary, based on the number of data')
plt.xlabel('Summary')
plt.ylabel('Precip Type')
plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\heatmap.png")
plt.show()

# %%
month= pd.to_datetime(Df["Date"]).dt.month
year = pd.to_datetime(Df["Date"]).dt.year

# months = ['January', 'March',  'May', 'July',
#            'September',  'November', '']


result2 = pd.pivot_table(data=Df, index=month, columns=year, values='Temperature (C)')
# %matplotlib inline
month_name = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(figsize=(7,7), nrows=2, gridspec_kw=grid_kws)
ax = sns.heatmap(result2, cbar_ax=cbar_ax, cbar_kws={"orientation": "horizontal"}, ax=ax,
                 yticklabels=month_name, annot=True , cmap=sns.color_palette("ch:s=-.2,r=.6", as_cmap=True))

ax.set_title('Temperature in Months of Years', fontsize=16, fontweight='bold')

ax.set_xlabel('Year')

plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\Temperature in Months of Years.png")

plt.show()

# %%
month= pd.to_datetime(Df["Date"]).dt.month
year = pd.to_datetime(Df["Date"]).dt.year

# months = ['January', 'March',  'May', 'July',
#            'September',  'November', '']


result2 = pd.pivot_table(data=Df, index=month, columns=year, values='Humidity')
# %matplotlib inline
month_name = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

grid_kws = {"height_ratios": (.9, .05), "hspace": .3}
f, (ax, cbar_ax) = plt.subplots(figsize=(7,7), nrows=2, gridspec_kw=grid_kws)
ax = sns.heatmap(result2, cbar_ax=cbar_ax, cbar_kws={"orientation": "horizontal"}, ax=ax,
                 yticklabels=month_name, annot=True , cmap=sns.color_palette("ch:s=-.2,r=.6", as_cmap=True))

ax.set_title('Temperature in Months of Years', fontsize=16, fontweight='bold')

ax.set_xlabel('Year')

plt.savefig("D:\ML\Data science\Tamrin\آب و هوای انگلیس\Humidity in Months of Years.png")

plt.show()
